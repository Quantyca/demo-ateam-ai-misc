# %% [markdown]
# # Rossmann: Generic (Stage1 - Prepare)

# %% [markdown]
# ## Intro

# %% [markdown]
# Keggle competition: [Rossmann Store Sales](https://www.kaggle.com/c/rossmann-store-sales)

# %% [markdown]
# ## Usage

# %% [markdown]
# **Input parameters**
# 1. RAW_TRAIN_CSV: Raw train data about sales
# 1. RAW_STORE_CSV:Raw train data about stores
# 1. PROCESSED_TRAIN_CSV:The name of the output file used to store the processed train data
#
# **Output**
# 1. A file with processed train data ready to be used for model training

# %% [markdown]
# ## Setup env

# %% [markdown]
# ### Set global variables

# %%
# !pwd
# Out:
# /opt/shared/notebooks

# %%
DATASETS_DIR = '../data'

# %%
# this cell is tagged `parameters`
RAW_TRAIN_CSV = DATASETS_DIR + '/raw/train.csv'
RAW_STORE_CSV = DATASETS_DIR + '/raw/store.csv'
PROCESSED_TRAIN_CSV = DATASETS_DIR + '/processed/tst-train.csv'

# %% [markdown]
# ###  Install required packages

# %% [markdown]
# Se il notebook è eseguito su una macchina pulita installare i pacchetti necessari con i seguenti comandi ...

# %%
#!curl https://raw.githubusercontent.com/andrea-gioia/boostrap.ai/master/fastai07colab	 | bash

# %% [markdown]
# Se il notebook è eseguito all'interno di un ambiente virtuale conda con tutti i pacchetti specificati nel file di requirements già installati fare solo un check eseguendo i seguenti comandi ...

# %% [markdown]
# ###  Dump environment

# %%
# !python -V
# Out:
# Python 3.7.3

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /opt/conda
# custom                *  /opt/conda/envs/custom

# %%
conda env export
# Out:
# name: custom
# channels:
#   - pytorch
#   - fastai
#   - conda-forge
#   - defaults
# dependencies:
#   - _py-xgboost-mutex=2.0=cpu_0
#   - asn1crypto=0.24.0=py37_0
#   - attrs=19.1.0=py37_1
#   - backcall=0.1.0=py37_0
#   - beautifulsoup4=4.7.1=py37_1
#   - blas=1.0=mkl
#   - bleach=3.1.0=py37_0
#   - bottleneck=1.2.1=py37h035aef0_1
#   - ca-certificates=2019.5.15=0
#   - certifi=2019.3.9=py37_0
#   - cffi=1.12.3=py37h2e261b9_0
#   - chardet=3.0.4=py37_1
#   - cryptography=2.6.1=py37h1ba5d50_0
#   - cudatoolkit=10.0.130=0
#   - cycler=0.10.0=py37_0
#   - cymem=2.0.2=py37hfd86e86_0
#   - cytoolz=0.9.0.1=py37h14c3975_1
#   - dataclasses=0.6=py_0
#   - dbus=1.13.6=h746ee38_0
#   - decorator=4.4.0=py37_1
#   - defusedxml=0.6.0=py_0
#   - dill=0.2.9=py37_0
#   - entrypoints=0.3=py37_0
#   - expat=2.2.6=he6710b0_0
#   - fastai=1.0.53.post2=1
#   - fastprogress=0.1.21=py_0
#   - fontconfig=2.13.0=h9420a91_0
#   - freetype=2.9.1=h8a8886c_1
#   - glib=2.56.2=hd408876_0
#   - gmp=6.1.2=h6c8ec71_1
#   - gst-plugins-base=1.14.0=hbbd80ab_1
#   - gstreamer=1.14.0=hb453b48_1
#   - icu=58.2=h9c2bf20_1
#   - idna=2.8=py37_0
#   - intel-openmp=2019.4=243
#   - ipykernel=5.1.1=py37h39e3cac_0
#   - ipython=7.5.0=py37h39e3cac_0
#   - ipython_genutils=0.2.0=py37_0
#   - ipywidgets=7.4.2=py37_0
#   - jedi=0.13.3=py37_0
#   - jinja2=2.10.1=py37_0
#   - jpeg=9b=h024ee3a_2
#   - jsonschema=3.0.1=py37_0
#   - jupyter=1.0.0=py37_7
#   - jupyter_client=5.2.4=py37_0
#   - jupyter_console=6.0.0=py37_0
#   - jupyter_core=4.4.0=py37_0
#   - kiwisolver=1.1.0=py37he6710b0_0
#   - libedit=3.1.20181209=hc058e9b_0
#   - libffi=3.2.1=hd88cf55_4
#   - libgcc-ng=9.1.0=hdf63c60_0
#   - libgfortran-ng=7.3.0=hdf63c60_0
#   - libpng=1.6.37=hbc83047_0
#   - libsodium=1.0.16=h1bed415_0
#   - libstdcxx-ng=9.1.0=hdf63c60_0
#   - libtiff=4.0.10=h2733197_2
#   - libuuid=1.0.3=h1bed415_2
#   - libxcb=1.13=h1bed415_1
#   - libxgboost=0.80=hf484d3e_1001
#   - libxml2=2.9.9=he19cac6_0
#   - markupsafe=1.1.1=py37h7b6447c_0
#   - matplotlib=2.2.3=py37hb69df0a_0
#   - mistune=0.8.4=py37h7b6447c_0
#   - mkl=2018.0.3=1
#   - mkl_fft=1.0.6=py37h7dd41cf_0
#   - mkl_random=1.0.1=py37h4414c95_1
#   - msgpack-numpy=0.4.3.2=py37_0
#   - msgpack-python=0.6.1=py37hfd86e86_1
#   - murmurhash=1.0.2=py37he6710b0_0
#   - nbconvert=5.5.0=py_0
#   - nbformat=4.4.0=py37_0
#   - ncurses=6.1=he6710b0_1
#   - ninja=1.9.0=py37hfd86e86_0
#   - notebook=5.7.8=py37_0
#   - numexpr=2.6.8=py37hd89afb7_0
#   - numpy=1.15.2=py37h1d66e8a_1
#   - numpy-base=1.15.2=py37h81de0dd_1
#   - nvidia-ml-py3=7.352.0=py_0
#   - olefile=0.46=py37_0
#   - openssl=1.1.1c=h7b6447c_1
#   - packaging=19.0=py37_0
#   - pandas=0.23.4=py37h04863e7_0
#   - pandoc=2.2.3.2=0
#   - pandocfilters=1.4.2=py37_1
#   - parso=0.4.0=py_0
#   - patsy=0.5.1=py37_0
#   - pcre=8.43=he6710b0_0
#   - pexpect=4.7.0=py37_0
#   - pickleshare=0.7.5=py37_0
#   - pillow=6.0.0=py37h34e0f95_0
#   - pip=19.1.1=py37_0
#   - plac=0.9.6=py37_0
#   - preshed=2.0.1=py37he6710b0_0
#   - prometheus_client=0.6.0=py37_0
#   - prompt_toolkit=2.0.9=py37_0
#   - ptyprocess=0.6.0=py37_0
#   - py-xgboost=0.80=py37hf484d3e_1001
#   - pycparser=2.19=py37_0
#   - pygments=2.4.2=py_0
#   - pyopenssl=19.0.0=py37_0
#   - pyparsing=2.4.0=py_0
#   - pyqt=5.9.2=py37h05f1152_2
#   - pyrsistent=0.14.11=py37h7b6447c_0
#   - pysocks=1.7.0=py37_0
#   - python=3.7.3=h0371630_0
#   - python-dateutil=2.8.0=py37_0
#   - pytorch=1.1.0=py3.7_cuda10.0.130_cudnn7.5.1_0
#   - pytz=2019.1=py_0
#   - pyyaml=5.1=py37h7b6447c_0
#   - pyzmq=18.0.0=py37he6710b0_0
#   - qt=5.9.7=h5867ecd_1
#   - qtconsole=4.5.1=py_0
#   - readline=7.0=h7b6447c_5
#   - regex=2018.01.10=py37h14c3975_1000
#   - requests=2.22.0=py37_0
#   - scikit-learn=0.20.0=py37h4989274_1
#   - scipy=1.1.0=py37hfa4b5c9_1
#   - seaborn=0.9.0=py37_0
#   - send2trash=1.5.0=py37_0
#   - setuptools=41.0.1=py37_0
#   - sip=4.19.8=py37hf484d3e_0
#   - six=1.12.0=py37_0
#   - soupsieve=1.8=py37_0
#   - spacy=2.0.18=py37hfc679d8_0
#   - sqlite=3.28.0=h7b6447c_0
#   - statsmodels=0.9.0=py37h035aef0_0
#   - terminado=0.8.2=py37_0
#   - testpath=0.4.2=py37_0
#   - thinc=6.12.1=py37h637b7d7_1000
#   - tk=8.6.8=hbc83047_0
#   - toolz=0.9.0=py37_0
#   - torchvision=0.3.0=py37_cu10.0.130_1
#   - tornado=6.0.2=py37h7b6447c_0
#   - tqdm=4.32.1=py_0
#   - traitlets=4.3.2=py37_0
#   - typing=3.6.4=py37_0
#   - ujson=1.35=py37h14c3975_0
#   - unzip=6.0=h611a1e1_0
#   - urllib3=1.24.2=py37_0
#   - wcwidth=0.1.7=py37_0
#   - webencodings=0.5.1=py37_1
#   - wheel=0.33.4=py37_0
#   - widgetsnbextension=3.4.2=py37_0
#   - wrapt=1.10.11=py37h14c3975_2
#   - xgboost=0.80=py37hf484d3e_1001
#   - xz=5.2.4=h14c3975_4
#   - yaml=0.1.7=had09818_2
#   - zeromq=4.3.1=he6710b0_3
#   - zlib=1.2.11=h7b6447c_3
#   - zstd=1.3.7=h0b5b093_0
# prefix: /opt/conda/envs/custom
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#!conda list

# %%
#!pip list

# %% [markdown]
# ### Import packages

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from fastai.imports import *

# fastai v0.7
#from fastai07.structured import *

# fastai v1.0
from fastai.tabular import *

#from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display
from pandas.api.types import is_string_dtype, is_numeric_dtype

from sklearn import metrics

# %% [markdown]
# ### Set random seed

# %%
# Set a seed value: 
seed_value= 42  


# Set `python` built-in pseudo-random generator at a fixed value: 
random.seed(seed_value) 

# Set `numpy` pseudo-random generator at a fixed value:
np.random.seed(seed_value) 

# Set `torch` pseudo-random generator at a fixed value:
torch.manual_seed(seed_value)
torch.backends.cudnn.deterministic = True 
torch.backends.cudnn.benchmark = False
    
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)

# %% [markdown]
# ### Define shared functions

# %%
def display_all(df):
    return
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
def train_cats(df):
    for n,c in df.items():
        if is_string_dtype(c): df[n] = c.astype('category').cat.as_ordered()

# %%
def numericalize(df, col, name, max_n_cat):
    if not is_numeric_dtype(col) and ( max_n_cat is None or len(col.cat.categories)>max_n_cat):
        df[name] = col.cat.codes+1

# %%
def fix_missing(df, col, name, na_dict):
    if is_numeric_dtype(col):
        if pd.isnull(col).sum() or (name in na_dict):
            df[name+'_na'] = pd.isnull(col)
            filler = na_dict[name] if name in na_dict else col.median()
            df[name] = col.fillna(filler)
            na_dict[name] = filler
    return na_dict

# %%
def proc_df(df, y_fld=None, skip_flds=None, ignore_flds=None, do_scale=False, na_dict=None,
            preproc_fn=None, max_n_cat=None, subset=None, mapper=None):
    if not ignore_flds: ignore_flds=[]
    if not skip_flds: skip_flds=[]
    if subset: df = get_sample(df,subset)
    else: df = df.copy()
    ignored_flds = df.loc[:, ignore_flds]
    df.drop(ignore_flds, axis=1, inplace=True)
    if preproc_fn: preproc_fn(df)
    if y_fld is None: y = None
    else:
        if not is_numeric_dtype(df[y_fld]): df[y_fld] = df[y_fld].cat.codes
        y = df[y_fld].values
        skip_flds += [y_fld]
    df.drop(skip_flds, axis=1, inplace=True)

    if na_dict is None: na_dict = {}
    else: na_dict = na_dict.copy()
    na_dict_initial = na_dict.copy()
    for n,c in df.items(): na_dict = fix_missing(df, c, n, na_dict)
    if len(na_dict_initial.keys()) > 0:
        df.drop([a + '_na' for a in list(set(na_dict.keys()) - set(na_dict_initial.keys()))], axis=1, inplace=True)
    if do_scale: mapper = scale_vars(df, mapper)
    for n,c in df.items(): numericalize(df, c, n, max_n_cat)
    df = pd.get_dummies(df, dummy_na=True)
    df = pd.concat([ignored_flds, df], axis=1)
    res = [df, y, na_dict]
    if do_scale: res = res + [mapper]
    return res

# %% [markdown]
# ## Stage 1: prepare

# %% [markdown]
# ### Load raw dataset

# %%
df_raw = pd.read_csv(RAW_TRAIN_CSV, low_memory=False, parse_dates=["Date"])

# %%
display_all(df_raw.tail().T)

# %%
display_all(df_raw.describe(include='all').T)

# %% [markdown]
# ### Load store dataset

# %%
df_store = pd.read_csv(RAW_STORE_CSV, low_memory=False)

# %%
display_all(df_store.tail().T)

# %%
display_all(df_store.describe(include='all').T)

# %% [markdown]
# ### Marge datasets (train+store)

# %%
df_raw = pd.merge(df_raw, df_store, on='Store')

# %%
display_all(df_raw.tail().T)

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Expand dates

# %%
#df_raw = df_raw.sort_values(['Date'])
dates = df_raw['Date']
add_datepart(df_raw, 'Date', drop=True)
# Out:
#          Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# 0            1          5   5263        555     1      1            0
# 1            1          4   5020        546     1      1            0
# 2            1          3   4782        523     1      1            0
# 3            1          2   5011        560     1      1            0
# 4            1          1   6102        612     1      1            0
# 5            1          7      0          0     0      0            0
# 6            1          6   4364        500     1      0            0
# 7            1          5   3706        459     1      0            0
# 8            1          4   3769        503     1      0            0
# 9            1          3   3464        463     1      0            0
# 10           1          2   3558        469     1      0            0
# 11           1          1   4395        526     1      0            0
# 12           1          7      0          0     0      0            0
# 13           1          6   4406        512     1      0            0
# 14           1          5   4852        519     1      1            0
# 15           1          4   4427        517     1      1            0
# 16           1          3   4767        550     1      1            0
# 17           1          2   5042        544     1      1            0
# 18           1          1   5054        553     1      1            0
# 19           1          7      0          0     0      0            0
# 20           1          6   3530        441     1      0            0
# 21           1          5   3808        449     1      0            0
# 22           1          4   3897        480     1      0            0
# 23           1          3   3797        485     1      0            0
# 24           1          2   3650        485     1      0            0
# 25           1          1   4359        540     1      0            0
# 26           1          7      0          0     0      0            0
# 27           1          6   4797        560     1      0            0
# 28           1          5   4665        538     1      1            0
# 29           1          4   5558        573     1      1            0
# ...        ...        ...    ...        ...   ...    ...          ...
# 1017179   1115          3   3813        287     1      0            0
# 1017180   1115          2   3397        277     1      0            0
# 1017181   1115          1   3615        271     1      0            0
# 1017182   1115          7      0          0     0      0            0
# 1017183   1115          6   4896        394     1      0            0
# 1017184   1115          5   5082        373     1      1            0
# 1017185   1115          4   5650        366     1      1            0
# 1017186   1115          3   5176        336     1      1            0
# 1017187   1115          2   5388        329     1      1            0
# 1017188   1115          1   3723        243     1      1            0
# 1017189   1115          7      0          0     0      0            0
# 1017190   1115          6   5207        369     1      0            0
# 1017191   1115          5   4287        296     1      0            0
# 1017192   1115          4   3039        244     1      0            0
# 1017193   1115          3   3064        237     1      0            0
# 1017194   1115          2   3528        277     1      0            0
# 1017195   1115          1   3158        252     1      0            0
# 1017196   1115          7      0          0     0      0            0
# 1017197   1115          6   4497        350     1      0            0
# 1017198   1115          5   5142        351     1      1            0
# 1017199   1115          4   5007        339     1      1            0
# 1017200   1115          3   4649        324     1      1            0
# 1017201   1115          2   5243        341     1      1            0
# 1017202   1115          1   6905        471     1      1            0
# 1017203   1115          7      0          0     0      0            0
# 1017204   1115          6   4771        339     1      0            0
# 1017205   1115          5   4540        326     1      0            0
# 1017206   1115          4   4297        300     1      0            0
# 1017207   1115          3   3697        305     1      0            0
# 1017208   1115          2      0          0     0      0            a
#
#          SchoolHoliday StoreType Assortment     ...      Day  Dayofweek  \
# 0                    1         c          a     ...       31          4
# 1                    1         c          a     ...       30          3
# 2                    1         c          a     ...       29          2
# 3                    1         c          a     ...       28          1
# 4                    1         c          a     ...       27          0
# 5                    0         c          a     ...       26          6
# 6                    0         c          a     ...       25          5
# 7                    0         c          a     ...       24          4
# 8                    0         c          a     ...       23          3
# 9                    0         c          a     ...       22          2
# 10                   0         c          a     ...       21          1
# 11                   0         c          a     ...       20          0
# 12                   0         c          a     ...       19          6
# 13                   0         c          a     ...       18          5
# 14                   0         c          a     ...       17          4
# 15                   0         c          a     ...       16          3
# 16                   0         c          a     ...       15          2
# 17                   0         c          a     ...       14          1
# 18                   0         c          a     ...       13          0
# 19                   0         c          a     ...       12          6
# 20                   0         c          a     ...       11          5
# 21                   0         c          a     ...       10          4
# 22                   0         c          a     ...        9          3
# 23                   0         c          a     ...        8          2
# 24                   0         c          a     ...        7          1
# 25                   0         c          a     ...        6          0
# 26                   0         c          a     ...        5          6
# 27                   0         c          a     ...        4          5
# 28                   0         c          a     ...        3          4
# 29                   0         c          a     ...        2          3
# ...                ...       ...        ...     ...      ...        ...
# 1017179              0         d          c     ...       30          2
# 1017180              0         d          c     ...       29          1
# 1017181              0         d          c     ...       28          0
# 1017182              0         d          c     ...       27          6
# 1017183              0         d          c     ...       26          5
# 1017184              0         d          c     ...       25          4
# 1017185              0         d          c     ...       24          3
# 1017186              0         d          c     ...       23          2
# 1017187              0         d          c     ...       22          1
# 1017188              0         d          c     ...       21          0
# 1017189              0         d          c     ...       20          6
# 1017190              0         d          c     ...       19          5
# 1017191              0         d          c     ...       18          4
# 1017192              0         d          c     ...       17          3
# 1017193              0         d          c     ...       16          2
# 1017194              0         d          c     ...       15          1
# 1017195              0         d          c     ...       14          0
# 1017196              0         d          c     ...       13          6
# 1017197              0         d          c     ...       12          5
# 1017198              1         d          c     ...       11          4
# 1017199              1         d          c     ...       10          3
# 1017200              1         d          c     ...        9          2
# 1017201              1         d          c     ...        8          1
# 1017202              1         d          c     ...        7          0
# 1017203              1         d          c     ...        6          6
# 1017204              1         d          c     ...        5          5
# 1017205              1         d          c     ...        4          4
# 1017206              1         d          c     ...        3          3
# 1017207              1         d          c     ...        2          2
# 1017208              1         d          c     ...        1          1
#
#          Dayofyear  Is_month_end  Is_month_start  Is_quarter_end  \
# 0              212          True           False           False
# 1              211         False           False           False
# 2              210         False           False           False
# 3              209         False           False           False
# 4              208         False           False           False
# 5              207         False           False           False
# 6              206         False           False           False
# 7              205         False           False           False
# 8              204         False           False           False
# 9              203         False           False           False
# 10             202         False           False           False
# 11             201         False           False           False
# 12             200         False           False           False
# 13             199         False           False           False
# 14             198         False           False           False
# 15             197         False           False           False
# 16             196         False           False           False
# 17             195         False           False           False
# 18             194         False           False           False
# 19             193         False           False           False
# 20             192         False           False           False
# 21             191         False           False           False
# 22             190         False           False           False
# 23             189         False           False           False
# 24             188         False           False           False
# 25             187         False           False           False
# 26             186         False           False           False
# 27             185         False           False           False
# 28             184         False           False           False
# 29             183         False           False           False
# ...            ...           ...             ...             ...
# 1017179         30         False           False           False
# 1017180         29         False           False           False
# 1017181         28         False           False           False
# 1017182         27         False           False           False
# 1017183         26         False           False           False
# 1017184         25         False           False           False
# 1017185         24         False           False           False
# 1017186         23         False           False           False
# 1017187         22         False           False           False
# 1017188         21         False           False           False
# 1017189         20         False           False           False
# 1017190         19         False           False           False
# 1017191         18         False           False           False
# 1017192         17         False           False           False
# 1017193         16         False           False           False
# 1017194         15         False           False           False
# 1017195         14         False           False           False
# 1017196         13         False           False           False
# 1017197         12         False           False           False
# 1017198         11         False           False           False
# 1017199         10         False           False           False
# 1017200          9         False           False           False
# 1017201          8         False           False           False
# 1017202          7         False           False           False
# 1017203          6         False           False           False
# 1017204          5         False           False           False
# 1017205          4         False           False           False
# 1017206          3         False           False           False
# 1017207          2         False           False           False
# 1017208          1         False            True           False
#
#         Is_quarter_start  Is_year_end  Is_year_start     Elapsed
# 0                  False        False          False  1438300800
# 1                  False        False          False  1438214400
# 2                  False        False          False  1438128000
# 3                  False        False          False  1438041600
# 4                  False        False          False  1437955200
# 5                  False        False          False  1437868800
# 6                  False        False          False  1437782400
# 7                  False        False          False  1437696000
# 8                  False        False          False  1437609600
# 9                  False        False          False  1437523200
# 10                 False        False          False  1437436800
# 11                 False        False          False  1437350400
# 12                 False        False          False  1437264000
# 13                 False        False          False  1437177600
# 14                 False        False          False  1437091200
# 15                 False        False          False  1437004800
# 16                 False        False          False  1436918400
# 17                 False        False          False  1436832000
# 18                 False        False          False  1436745600
# 19                 False        False          False  1436659200
# 20                 False        False          False  1436572800
# 21                 False        False          False  1436486400
# 22                 False        False          False  1436400000
# 23                 False        False          False  1436313600
# 24                 False        False          False  1436227200
# 25                 False        False          False  1436140800
# 26                 False        False          False  1436054400
# 27                 False        False          False  1435968000
# 28                 False        False          False  1435881600
# 29                 False        False          False  1435795200
# ...                  ...          ...            ...         ...
# 1017179            False        False          False  1359504000
# 1017180            False        False          False  1359417600
# 1017181            False        False          False  1359331200
# 1017182            False        False          False  1359244800
# 1017183            False        False          False  1359158400
# 1017184            False        False          False  1359072000
# 1017185            False        False          False  1358985600
# 1017186            False        False          False  1358899200
# 1017187            False        False          False  1358812800
# 1017188            False        False          False  1358726400
# 1017189            False        False          False  1358640000
# 1017190            False        False          False  1358553600
# 1017191            False        False          False  1358467200
# 1017192            False        False          False  1358380800
# 1017193            False        False          False  1358294400
# 1017194            False        False          False  1358208000
# 1017195            False        False          False  1358121600
# 1017196            False        False          False  1358035200
# 1017197            False        False          False  1357948800
# 1017198            False        False          False  1357862400
# 1017199            False        False          False  1357776000
# 1017200            False        False          False  1357689600
# 1017201            False        False          False  1357603200
# 1017202            False        False          False  1357516800
# 1017203            False        False          False  1357430400
# 1017204            False        False          False  1357344000
# 1017205            False        False          False  1357257600
# 1017206            False        False          False  1357171200
# 1017207            False        False          False  1357084800
# 1017208             True        False           True  1356998400
#
# [1017209 rows x 30 columns]

# %%
display_all(df_raw.tail().T)

# %%
df_raw.Year.head()
# Out:
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# Name: Year, dtype: int64

# %% [markdown]
# ### Convert cotegorical features

# %%
train_cats(df_raw)

# %%
display_all(df_raw.describe(include='all').T)

# %% [markdown]
# Sembra che le categorie siano già correttamente ordinata ...

# %%
df_raw.StoreType.cat.categories
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df_raw.Assortment.cat.categories
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# ...  non dobbiamo pertanto  procedere al riordino
#
#
# ```
# df_raw.StoreType.cat.set_categories(['a', 'b', 'c', 'd'], ordered=True, inplace=True)
# ```

# %%
df_raw.StoreType.cat.codes[:5]
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# dtype: int8

# %% [markdown]
# ### Handle missing values

# %%
display_all(df_raw.isnull().sum().sort_index()/len(df_raw))

# %%
df_raw.shape
# Out:
# (1017209, 30)

# %% [markdown]
# We'll replace categories with their numeric codes, handle missing continuous values, and split the dependent variable into a separate variable.

# %%
X_train, y_train, nas = proc_df(df_raw, 'Sales')

# %%
display_all(X_train.isnull().sum().sort_index()/len(X_train))

# %%
df_raw['Sales'][-5:]
# Out:
# 1017204    4771
# 1017205    4540
# 1017206    4297
# 1017207    3697
# 1017208       0
# Name: Sales, dtype: int64

# %%
y_train[-5:]
# Out:
# array([4771, 4540, 4297, 3697,    0])

# %% [markdown]
# ### Save prepared data

# %%
X_train.shape, y_train.shape
# Out:
# ((1017209, 34), (1017209,))

# %%
display_all(df_raw.tail().T)

# %%
y_train = pd.DataFrame(y_train,columns=["Sales"])
y_train[-5:]
# Out:
#          Sales
# 1017204   4771
# 1017205   4540
# 1017206   4297
# 1017207   3697
# 1017208      0

# %%
df_processed_train = pd.concat([X_train, y_train], axis = 1);
df_processed_train = pd.concat([df_processed_train, dates], axis = 1);
df_processed_train.shape, display_all(df_processed_train.tail().T)
# Out:
# ((1017209, 36), None)

# %%
nas
# Out:
# {'CompetitionDistance': 2330.0,
#  'CompetitionOpenSinceMonth': 8.0,
#  'CompetitionOpenSinceYear': 2010.0,
#  'Promo2SinceWeek': 22.0,
#  'Promo2SinceYear': 2012.0}

# %%
df_processed_train = df_processed_train.sort_values(['Date'])
display_all(df_processed_train.tail().T)

# %%
df_processed_train.to_csv(PROCESSED_TRAIN_CSV)

# %%
# END
